# %% [markdown]
# # Network Analysis
#
# Recreate the supplied graph definitions and inspect verified structural metrics.
#
# **Student:** S. M. Monowar Kayser (253-25-019)
# **Course:** Data Visualization (CSE628), Summer 2026

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print('Project root:', ROOT)
# Out:
# Project root: E:\MSC_Data_Visualization

# %%
from src.graph_generators import build_transport_graph, build_ppi_graph, graph_metrics
G_transport = build_transport_graph()
G_ppi = build_ppi_graph()
print('G_transport:', graph_metrics(G_transport))
print('G_ppi:', graph_metrics(G_ppi))
# Out:
# G_transport: {'nodes': 7, 'edges': 9, 'density': 0.42857142857142855, 'average_degree': 2.5714285714285716, 'average_clustering': 0.8857142857142858, 'connected': True, 'connected_components': 1, 'average_shortest_path': 1.5714285714285714, 'average_shortest_path_scope': 'whole graph', 'maximum_degree': 6, 'degree_standard_deviation': 1.3997084244475304}
# G_ppi: {'nodes': 15, 'edges': 15, 'density': 0.14285714285714285, 'average_degree': 2.0, 'average_clustering': 0.0, 'connected': True, 'connected_components': 1, 'average_shortest_path': 3.619047619047619, 'average_shortest_path_scope': 'whole graph', 'maximum_degree': 4, 'degree_standard_deviation': 0.9660917830792959}

# %% [markdown]
# The transportation graph is an undirected weighted teaching example. The protein graph is the exact seeded Watts-Strogatz construction from Section 8.3.
